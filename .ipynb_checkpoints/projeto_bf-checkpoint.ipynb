# %%
import pandas as pd 
import math
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Produto_Escolhido--Battlefield5.xlsx")

# %%
df.dropna(inplace=True)

# %%
Battlefilho = df.loc[:, ['Treinamento','Categoria']] 

Battlefilho_idx = Battlefilho.set_index('Treinamento')

Battlefilho_idx['Categoria'].value_counts()
# Out:
# 0    272
# 1     28
# Name: Categoria, dtype: int64

# %%
def poisson(x, lamb):
    P = (math.e**(-lamb) * lamb**x) / math.factorial(x)
    return P
    
def bernoulli(p, x):
    P = p**x * (1-p)**(1-x)
    return P

def bin_newton(x, n):
    b = math.factorial(n) / (math.factorial(n-x) *  math.factorial(x))

def binomial(p, x, n):
    P = bin_newton(x, n) * p**x * (1-p)**()

# %%
Battlefilho_idx.head()
# Out:
#                                                     Categoria
# Treinamento
# who needs #windows when even a pre-release aaa ...          0
# rt @battlefield: 🔴 go, go, go! \nthe #battlefie...          0
# battlefield v beta 🎮 ps4 gameplay live: https:/...          0
# rt @battlefield: 🔴 go, go, go! \nthe #battlefie...          0
# rt @vicenteprod: battlefield v - this is specta...          0

# %%
texto_df = Battlefilho_idx[Battlefilho_idx.Categoria==1].index
lista_texto = list(texto_df)
textao = " ".join(lista_texto)
split_txt = textao.split()
pandas_txt = pd.Series(split_txt)

# %%
pandas_txt.value_counts()
# Out:
# the             29
# v               23
# battlefield     21
# to              16
# is              15
# on              13
# i               12
# ✅               12
# and             12
# beta            11
# a               11
# rt               7
# this             7
# with             6
# my               6
# of               6
# was              5
# get              5
# so               5
# me               5
# @battlefield     5
# game             5
# it               5
# at               5
# just             5
# .                4
# then             4
# never            4
# be               4
# but              4
#                 ..
# @rinsenpai:      1
# anymore,         1
# &amp;            1
# game???          1
# though.          1
# want             1
# anyone           1
# lag              1
# matchmaking      1
# atm              1
# me.              1
# disappointed     1
# currently        1
# 6                1
# issue            1
# far              1
# appered.         1
# console          1
# problems         1
# girls            1
# them             1
# bar              1
# £20              1
# sends            1
# bojack           1
# issues           1
# bad,             1
# keeps            1
# think            1
# install”         1
# Length: 359, dtype: int64

# %%
texto_df2 = Battlefilho_idx[Battlefilho_idx.Categoria==1]
texto_df2
# Out:
#                                                     Categoria
# Treinamento
# battlefield v beta is the bizness                           1
# rt @battlefield: ✅ 8 multiplayer modes\n✅ singl...          1
# as a @battlefield fan since bad company two .\n...          1
# battlefield v beta is amazing, definitely purch...          1
# @eahelp the battlefield v bèta won't  work anym...          1
# 15 minutes of the battlefield v beta and that s...          1
# rt @battlefield: our buddy @vicenteprod deliver...          1
# @kallumtanton @xiaobaozha @tomshardware @ea_dic...          1
# rainbow 6 siege looks better at low settings an...          1
# anybody else having problems getting into serve...          1
# the amount of people playing right now on ps4/p...          1
# rt @adenough: @battlefield listen up guys and g...          1
# anyone else having trouble getting into any gam...          1
# this new "battlefield v: matchmaking failed" si...          1
# rt @battlefield: ✅ 8 multiplayer modes\n✅ singl...          1
# that battlefield v 😍😍                                       1
# rt @rinsenpai: i love the new battlefield v tra...          1
# battlefield v is pretty disappointing :( feels ...          1
# rt @bfbulletin: psa for #pc players: the latest...          1
# @battlefield v not off to a good start.. entere...          1
# spiderman on my #ps4\nbattlefield v beta on my ...          1
# @crafterytube @kingslayertommy @fabianchills @g...          1
# battlefield v runs like crap on my pc, the fram...          1
# battlefield v is actually pretty smooth and the...          1
# i tried playing the battlefield v open beta on ...          1
# rt @battlefield: ✅ 8 multiplayer modes\n✅ singl...          1
# can’t download the battlefield v beta and i wan...          1
# @eaaccess what is going, on i’m trying to downl...          1
